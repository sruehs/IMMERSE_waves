# %% [markdown]
# # Calculating Lagrangian trajectories from ocean-only (uncoupled)  and ocean-wave (coupled) model simulations for the MedSea

# %% [markdown]
# ## 1. General Settings

# %% [markdown]
# ### 1.1 Load modules and check versions

# %%
from glob import glob
from datetime import timedelta, datetime
import math

from parcels import (FieldSet, ParticleSet,
                     JITParticle, ScipyParticle,
                     AdvectionRK4,
                     Variable, Field, VectorField)
import xarray as xr
import numpy as np

# %matplotlib inline

# %%
# modified after: https://stackoverflow.com/questions/40428931/package-for-listing-version-of-packages-used-in-a-jupyter-notebook
## make sure to use Parcels version 2.4.0 or later for zarr output

import pkg_resources
import types
def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            # Split ensures you get root package, 
            # not just imported function
            name = val.__name__.split(".")[0]

        elif isinstance(val, type):
            name = val.__module__.split(".")[0]            
        yield name
imports = list(set(get_imports()))
# get the version of the root package from only the name of the package
# via cross-checking the names of installed packages vs. imported packages
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name!="pip":
        requirements.append((m.project_name, m.version))
for r in requirements:
    print("{}=={}".format(*r))
# Out:
# xarray==2022.12.0
# parcels==2.4.0
# numpy==1.24.1

# %% [markdown]
# ### 1.2 Define general custom functions

# %%
# DEFINE ALTERNATIVE TO USE NP.ARANGE
#
# from https://stackoverflow.com/questions/50299172/python-range-or-numpy-arange-with-end-limit-include
# (code posted by Markus Dutschke on Aug 2nd 2019, last accessed on Dec 6th 2023)
#
# WHY using it? 
# In principal, values are generated within the half-open interval [start, stop)
# (in other words, the interval including start but excluding stop). 
# Yet, unfortunately, when using a non-integer step (such as 0.1), 
# the results of np.arange are often not consistent. 
# Specifically, they sometimes do include the stop value.
# It is better to use the following function based on numpy.linspace for these cases

def cust_range(*args, rtol=1e-05, atol=1e-08, include=[True, False]):
    """
    Combines numpy.arange and numpy.isclose to mimic
    open, half-open and closed intervals.
    Avoids also floating point rounding errors as with
    >>> numpy.arange(1, 1.3, 0.1)
    array([1. , 1.1, 1.2, 1.3])

    args: [start, ]stop, [step, ]
        as in numpy.arange
    rtol, atol: floats
        floating point tolerance as in numpy.isclose
    include: boolean list-like, length 2
        if start and end point are included
    """
    # process arguments
    if len(args) == 1:
        start = 0
        stop = args[0]
        step = 1
    elif len(args) == 2:
        start, stop = args
        step = 1
    else:
        assert len(args) == 3
        start, stop, step = tuple(args)

    # determine number of segments
    n = (stop-start)/step + 1

    # do rounding for n
    if np.isclose(n, np.round(n), rtol=rtol, atol=atol):
        n = np.round(n)

    # correct for start/end is exluded
    if not include[0]:
        n -= 1
        start += step
    if not include[1]:
        n -= 1
        stop -= step

    return np.linspace(start, stop, int(n))

def crange(*args, **kwargs):
    return cust_range(*args, **kwargs, include=[True, True])

def orange(*args, **kwargs):
    return cust_range(*args, **kwargs, include=[True, False])

print("crange(1, 1.3, 0.1) >>>", crange(1, 1.3, 0.1))
print("orange(1, 1.3, 0.1) >>>", orange(1, 1.3, 0.1))
print("crange(0.0, 0.6, 0.2) >>>", crange(0.0, 0.6, 0.2))
print("orange(0.0, 0.6, 0.2) >>>", orange(0.0, 0.6, 0.2))
# Out:
# crange(1, 1.3, 0.1) >>> [1.  1.1 1.2 1.3]
# orange(1, 1.3, 0.1) >>> [1.  1.1 1.2]
# crange(0.0, 0.6, 0.2) >>> [0.  0.2 0.4 0.6]
# orange(0.0, 0.6, 0.2) >>> [0.  0.2 0.4]

# %% [markdown]
# ## 2. Custom settings Parcels
# !!! IMPORTANT: need to be checked/adjusted before every execution !!! Particularly check the parts highlighted within lines of #### !!!

# %% [markdown]
# ### 2.1 Define input paths

# %%
############################

# set key to 'uncoupled', 'uncoupled_sd', 'coupled_nosd', or 'coupled_sd'
key_input = 'coupled_sd'

# define whether ocean velocity is sampled (key_sample_velocity = True)
key_sample_velocity = True

############################

datapath = '/Users/siren/Data/IMMERSE/'
# path were original velocity putput is stored

gridpath = (datapath + 'domain/fgrid.nc')
# path were model grid info is stored

if (key_input == 'uncoupled') or (key_input == 'uncoupled_sd'):
    filepaths_u = sorted(glob(datapath + 'surface_TKE_UNC/MED24_OBC_1d*_grid_U.nc'))
    filepaths_v = sorted(glob(datapath + 'surface_TKE_UNC/MED24_OBC_1d*_grid_V.nc'))
    if key_input == 'uncoupled':
        key_stokes = False
        print('calculate trajectories for uncoupled simulation without additional consideration of Stokes drift')
    elif key_input == 'uncoupled_sd':
        key_stokes = True
        filepaths_usd = sorted(glob(datapath + 'surface_TKE_CO/MED24_OBC_1d*_grid_U.nc'))
        filepaths_vsd = sorted(glob(datapath + 'surface_TKE_CO/MED24_OBC_1d*_grid_V.nc'))
        print('calculate trajectories for uncoupled simulation without additional consideration of Stokes drift')

elif (key_input == 'coupled_nosd') or (key_input == 'coupled_sd'):
    filepaths_u = sorted(glob(datapath + 'surface_TKE_CO/MED24_OBC_1d*_grid_U.nc'))
    filepaths_v = sorted(glob(datapath + 'surface_TKE_CO/MED24_OBC_1d*_grid_V.nc'))
    if key_input == 'coupled_nosd':
        key_stokes = False
        print('calculate trajectories for coupled simulation without explicit consideration of Stokes drift')
    elif key_input == 'coupled_sd':
        key_stokes = True
        filepaths_usd = filepaths_u
        filepaths_vsd = filepaths_v
        print('calculate trajectories for coupled simulation with explicit consideration of Stokes drift')

else:
    print('no (valid) key_input defined')
# Out:
# calculate trajectories for coupled simulation with explicit consideration of Stokes drift

# %% [markdown]
# ###  2.2 Define Particle release grid

# %%
############################

# release_name can be 
# - "GulfOfLion" (particles released every 5 days over one year), or
# - "Test" (particles released over one time step only)

release_name = 'SubReg9'

############################

tstart_release = 0 # first release time in time steps of input data set after start of input data set (here: daily)
deltat_release = 5 # release from the same set of locations every deltat_release time steps

times_convert = 86400 # time step of input data in seconds (here: daily)

if release_name == "Test":
    tend_release = 10 
else:
    tend_release = 365 
# in time steps of input data set after start of input data set

if (release_name == 'GulfOfLion') or (release_name == 'Test'):
    lonmin = 3
    lonmax = 5.6
    latmin = 42.1
    latmax = 43.5
    step = 0.05 #(appr. every grid cell)

if release_name == 'SubReg9':
    lonmin = 15.0
    lonmax = 17.0
    latmin = 36.1
    latmax = 38.1
    step = 0.05 #(appr. every grid cell)

if release_name == 'SubReg14':
    lonmin = 30.3
    lonmax = 32.3
    latmin = 35
    latmax = 37
    step = 0.05 #(appr. every grid cell)

if release_name == 'SubReg7':
    lonmin = 10
    lonmax = 12
    latmin = 33
    latmax = 35.3
    step = 0.05 #(appr. every grid cell)
    
lons, lats = np.meshgrid(crange(lonmin, lonmax, step),
                         crange(latmin, latmax, step))
n_releasepos = lons.shape[0]*lons.shape[1]
n_particles = n_releasepos * ((tend_release-tstart_release)/deltat_release)
print("maximum number of release positions (including land):", n_releasepos)
print("maximum number of particles (including land):", int(n_particles))
# Out:
# maximum number of release positions (including land): 1681
# maximum number of particles (including land): 122713

# %% [markdown]
# ### 2.3 Define Lagrangian trajectory integration parameters

# %%
tint = 30 # in days
deltat = 25 # in minutes
# How to chose deltat (Schmidt et al., 2021):
### The time step dt should be small enough that particles do not skip grid cells
### and thereby miss characteristic oceanographic features. 
### Due to trade-off between accuracy of time stepping and computation time, the integration
### time step dt was chosen such that particles stay in one model grid cell for at least 2dt
### Therefore, a time step dt can be calculated following dt<dsmin/(vmax⋅2)
### where dsmin is the smallest edge of all grid cells in the domain and
### vmax is the largest horizontal velocity.
### assume vmax = 1m/s, dsmin = 1/24 = 3000 m : dt < (3000 / 2)s = 1500 s = 25 min 
### (at 45N - northern boundary MedSea - 1deg lon is appr. 79km -> 1/24 deg = 3300m;
### 1 deg lat is 111km)

pclass = JITParticle # can be JITParticle or ScipyParticle

# %% [markdown]
# ### 2.4 Define Lagrangian trajectory output

# %%
############################

outdt = 1 #in days

############################

procpath = '/Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/' + release_name +'/'
! mkdir -p $procpath #creates output folder if it does not exist yet

if key_input == 'uncoupled':
    outpath = (procpath + 'Parcels_CalcTraj_Data-uncoupled_Release-' + release_name)
if key_input == 'uncoupled_sd':
    outpath = (procpath + 'Parcels_CalcTraj_Data-uncoupled-sd_Release-' + release_name)
elif key_input == 'coupled_nosd':
    outpath = (procpath + 'Parcels_CalcTraj_Data-coupled-nosd_Release-' + release_name)
elif key_input == 'coupled_sd':
    outpath = (procpath + 'Parcels_CalcTraj_Data-coupled-sd_Release-' + release_name)

# %% [markdown]
# ## 3. Execution of parcels simulation

# %% [markdown]
# ### 3.1 Create custom Parcels functions

# %%
def create_fieldset(keystokes=False):
    
    filenames = {'U': {'lon': gridpath, 'lat': gridpath, 'data': filepaths_u},
                 'V': {'lon': gridpath, 'lat': gridpath, 'data': filepaths_v}}
    variables = {'U': 'vozocrtx',
                 'V': 'vomecrty'}
    dimensions = {'U': {'lon': 'glamf', 'lat': 'gphif', 'time': 'time_counter'},
                  'V': {'lon': 'glamf', 'lat': 'gphif', 'time': 'time_counter'}}
    fieldset = FieldSet.from_nemo(filenames, variables, dimensions,
                                  mesh='spherical',
                                  allow_time_extrapolation=False,
                                  time_periodic=False)
        
    if keystokes == True:
        filenames_sd = {'U': {'lon': gridpath, 'lat': gridpath, 'data': filepaths_usd},
                        'V': {'lon': gridpath, 'lat': gridpath, 'data': filepaths_vsd}}
        variables_sd = {'U': 'usd',
                        'V': 'vsd'}
        fieldset_sd = FieldSet.from_nemo(filenames_sd, variables_sd, dimensions,
                                         mesh='spherical',
                                         allow_time_extrapolation=False,
                                         time_periodic=False)
        fieldset_sum = FieldSet(U=fieldset.U+fieldset_sd.U,
                                V=fieldset.V+fieldset_sd.V)
        fieldset_use = fieldset_sum
    elif keystokes == False:
        fieldset_use = fieldset
        
    return fieldset_use

# %% [markdown]
# Kernels partially adopted and modified from https://github.com/OceanParcels/Parcelsv2.0PaperNorthSeaScripts

# %%
class BeachParticle(pclass):
    # beached : 0 sea, 1 beached, 2 after non-beach dyn
    beached = Variable('beached', dtype=np.int64, initial=2)

# %%
class BeachCurrentParticle(pclass):
    # beached : 0 sea, 1 beached, 2 after non-beach dyn
    beached = Variable('beached', dtype=np.int64, initial=0)
    U = Variable('U', dtype=np.float32, initial=0)
    V = Variable('V', dtype=np.float32, initial=0)

# %%
def AdvectionRK4(particle, fieldset, time):
    if particle.beached == 0:
        (u1, v1) = fieldset.UV[time, particle.depth, particle.lat, particle.lon]
        lon1, lat1 = (particle.lon + u1*.5*particle.dt, particle.lat + v1*.5*particle.dt)

        (u2, v2) = fieldset.UV[time + .5 * particle.dt, particle.depth, lat1, lon1]
        lon2, lat2 = (particle.lon + u2*.5*particle.dt, particle.lat + v2*.5*particle.dt)

        (u3, v3) = fieldset.UV[time + .5 * particle.dt, particle.depth, lat2, lon2]
        lon3, lat3 = (particle.lon + u3*particle.dt, particle.lat + v3*particle.dt)

        (u4, v4) = fieldset.UV[time + particle.dt, particle.depth, lat3, lon3]
        particle.lon += (u1 + 2*u2 + 2*u3 + u4) / 6. * particle.dt
        particle.lat += (v1 + 2*v2 + 2*v3 + v4) / 6. * particle.dt
        particle.beached = 2

# %%
def SampleUV(particle, fieldset, time):
    # attention: samples particle velocity in deg/s and needs to be converted to m/s
    # also note that fieldset is sampled at time+particle.dt, as first advection id performed and positions are updated,
    # then fieldset is sampled at new location and time+dt, the time is updated
    ## this procedure will probably not be necessary with future parcel releases
    particle.U, particle.V = fieldset.UV[particle.time+particle.dt, particle.depth, particle.lat, particle.lon]

# %%
def BeachTesting(particle, fieldset, time):
    if particle.beached == 2:
        (u, v) = fieldset.UV[particle.time+particle.dt, particle.depth, particle.lat, particle.lon]
        # if velocity threshold ist set to 1e-8 (suggestion Christian) artificial beaching occurs
        # -> do NOT do that
        if math.fabs(u) < 1e-14 and math.fabs(v) < 1e-14:
            particle.beached = 1
            print("Particle [%d] beached !! (%g %g %g %g)" % (particle.id, particle.lon, particle.lat, particle.depth, particle.time+particle.dt))
        else:
            particle.beached = 0

# %%
def BeachTesting_initial(particle, fieldset, time):
    if particle.beached == 2:
        (u, v) = fieldset.UV[particle.time, particle.depth, particle.lat, particle.lon]
        # if velocity threshold ist set to 1e-8 (suggestion Christian) artificial beaching occurs 
        #-> do NOT do that
        if math.fabs(u) < 1e-14 and math.fabs(v) < 1e-14:
            particle.beached = 1
            print("Particle [%d] beached !! (%g %g %g %g)" % (particle.id, particle.lon, particle.lat, particle.depth, particle.time))
        else:
            particle.beached = 0

# %%
def DeleteParticle(particle, fieldset, time):
    if particle.beached == 1:
        particle.delete()
        print("Particle [%d] deleted !! (%g %g %g %g)" % (particle.id, particle.lon, particle.lat, particle.depth, particle.time))

# %%
def PlotParticleSet(pset,fieldset):
    plotstep=4
    pset.show(field=fieldset.U,
              domain={'N':(latmax+plotstep/2),'S':(latmin-plotstep),
                      'E': (lonmax+plotstep), 'W':(lonmin-plotstep)})

# %%
def PlotParticleSet(pset,fieldset):
    plotstep=2 #for larger values velocity field will be sampled out of bounds with our chosen release regions
    pset.show(field=fieldset.U,
              domain={'N':(latmax+plotstep),'S':(latmin-plotstep),
                      'E': (lonmax+plotstep), 'W':(lonmin-plotstep)})

# %% [markdown]
# ### 3.2 Determine exact particle release positions (mask land positions)

# %%
# release particles on predefined uniform grid, including land grid points
fieldset_init = create_fieldset(keystokes=False)
pset_init = ParticleSet(fieldset=fieldset_init,
                        pclass=BeachParticle,
                        lon=lons, lat=lats, time=0)
pset_init.populate_indices()
PlotParticleSet(pset_init,fieldset_init)
print('maximum number of release positions (including land):',pset_init.lon.size)
print()
lons_prelim = pset_init.lon
lats_prelim = pset_init.lat

# perform a "fake" integration to determine and delete particles released on land
## by making use of beach-testing and deleting kernels
## (without advection kernel)
kernels_init = pset_init.Kernel(BeachTesting_initial) + pset_init.Kernel(DeleteParticle)
pset_init.execute(kernels_init, dt=0)
PlotParticleSet(pset_init,fieldset_init)

# retrieve lon and lats from all ocean release positions
print("actual number of release positions (excluding land):", pset_init.lon.size)
print("actual number of particles:",
      pset_init.lon.size * ((tend_release-tstart_release)/deltat_release))
lons_use = pset_init.lon
lats_use = pset_init.lat
# Out:
# maximum number of release positions (including land): 1681
# INFO: Compiled ArrayBeachParticleBeachTesting_initialDeleteParticle ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib0d96d4ddd00ee8eda68414f864f07828_0.so
# WARNING: dt or runtime are zero, or endtime is equal to Particle.time. The kernels will be executed once, without incrementing time
# Particle [453] beached !! (15.1 36.65 0 0)
# Particle [493] beached !! (15.05 36.7 0 0)
# Particle [494] beached !! (15.1 36.7 0 0)
# Particle [533] beached !! (15 36.75 0 0)
# Particle [534] beached !! (15.05 36.75 0 0)
# Particle [535] beached !! (15.1 36.75 0 0)
# Particle [574] beached !! (15 36.8 0 0)
# Particle [575] beached !! (15.05 36.8 0 0)
# Particle [576] beached !! (15.1 36.8 0 0)
# Particle [615] beached !! (15 36.85 0 0)
# Particle [616] beached !! (15.05 36.85 0 0)
# Particle [617] beached !! (15.1 36.85 0 0)
# Particle [656] beached !! (15 36.9 0 0)
# Particle [657] beached !! (15.05 36.9 0 0)
# Particle [658] beached !! (15.1 36.9 0 0)
# Particle [697] beached !! (15 36.95 0 0)
# Particle [698] beached !! (15.05 36.95 0 0)
# Particle [699] beached !! (15.1 36.95 0 0)
# Particle [700] beached !! (15.15 36.95 0 0)
# Particle [738] beached !! (15 37 0 0)
# Particle [739] beached !! (15.05 37 0 0)
# Particle [740] beached !! (15.1 37 0 0)
# Particle [741] beached !! (15.15 37 0 0)
# Particle [742] beached !! (15.2 37 0 0)
# Particle [743] beached !! (15.25 37 0 0)
# Particle [779] beached !! (15 37.05 0 0)
# Particle [780] beached !! (15.05 37.05 0 0)
# Particle [781] beached !! (15.1 37.05 0 0)
# Particle [782] beached !! (15.15 37.05 0 0)
# Particle [783] beached !! (15.2 37.05 0 0)
# Particle [784] beached !! (15.25 37.05 0 0)
# Particle [785] beached !! (15.3 37.05 0 0)
# Particle [820] beached !! (15 37.1 0 0)
# Particle [821] beached !! (15.05 37.1 0 0)
# Particle [822] beached !! (15.1 37.1 0 0)
# Particle [823] beached !! (15.15 37.1 0 0)
# Particle [824] beached !! (15.2 37.1 0 0)
# Particle [825] beached !! (15.25 37.1 0 0)
# Particle [826] beached !! (15.3 37.1 0 0)
# Particle [861] beached !! (15 37.15 0 0)
# Particle [862] beached !! (15.05 37.15 0 0)
# Particle [863] beached !! (15.1 37.15 0 0)
# Particle [864] beached !! (15.15 37.15 0 0)
# Particle [865] beached !! (15.2 37.15 0 0)
# Particle [902] beached !! (15 37.2 0 0)
# Particle [903] beached !! (15.05 37.2 0 0)
# Particle [904] beached !! (15.1 37.2 0 0)
# Particle [905] beached !! (15.15 37.2 0 0)
# Particle [943] beached !! (15 37.25 0 0)
# Particle [944] beached !! (15.05 37.25 0 0)
# Particle [945] beached !! (15.1 37.25 0 0)
# Particle [946] beached !! (15.15 37.25 0 0)
# Particle [984] beached !! (15 37.3 0 0)
# Particle [985] beached !! (15.05 37.3 0 0)
# Particle [986] beached !! (15.1 37.3 0 0)
# Particle [1025] beached !! (15 37.35 0 0)
# Particle [1026] beached !! (15.05 37.35 0 0)
# Particle [1027] beached !! (15.1 37.35 0 0)
# Particle [1066] beached !! (15 37.4 0 0)
# Particle [1067] beached !! (15.05 37.4 0 0)
# Particle [1068] beached !! (15.1 37.4 0 0)
# Particle [1107] beached !! (15 37.45 0 0)
# Particle [1108] beached !! (15.05 37.45 0 0)
# Particle [1109] beached !! (15.1 37.45 0 0)
# Particle [1148] beached !! (15 37.5 0 0)
# Particle [1149] beached !! (15.05 37.5 0 0)
# Particle [1150] beached !! (15.1 37.5 0 0)
# Particle [1189] beached !! (15 37.55 0 0)
# Particle [1190] beached !! (15.05 37.55 0 0)
# Particle [1191] beached !! (15.1 37.55 0 0)
# Particle [1230] beached !! (15 37.6 0 0)
# Particle [1231] beached !! (15.05 37.6 0 0)
# Particle [1232] beached !! (15.1 37.6 0 0)
# Particle [1233] beached !! (15.15 37.6 0 0)
# Particle [1271] beached !! (15 37.65 0 0)
# Particle [1272] beached !! (15.05 37.65 0 0)
# Particle [1273] beached !! (15.1 37.65 0 0)
# Particle [1274] beached !! (15.15 37.65 0 0)
# Particle [1312] beached !! (15 37.7 0 0)
# Particle [1313] beached !! (15.05 37.7 0 0)
# Particle [1314] beached !! (15.1 37.7 0 0)
# Particle [1315] beached !! (15.15 37.7 0 0)
# Particle [1353] beached !! (15 37.75 0 0)
# Particle [1354] beached !! (15.05 37.75 0 0)
# Particle [1355] beached !! (15.1 37.75 0 0)
# Particle [1356] beached !! (15.15 37.75 0 0)
# Particle [1357] beached !! (15.2 37.75 0 0)
# Particle [1394] beached !! (15 37.8 0 0)
# Particle [1395] beached !! (15.05 37.8 0 0)
# Particle [1396] beached !! (15.1 37.8 0 0)
# Particle [1397] beached !! (15.15 37.8 0 0)
# Particle [1398] beached !! (15.2 37.8 0 0)
# Particle [1399] beached !! (15.25 37.8 0 0)
# Particle [1435] beached !! (15 37.85 0 0)
# Particle [1436] beached !! (15.05 37.85 0 0)
# Particle [1437] beached !! (15.1 37.85 0 0)
# Particle [1438] beached !! (15.15 37.85 0 0)
# Particle [1439] beached !! (15.2 37.85 0 0)
# Particle [1440] beached !! (15.25 37.85 0 0)
# Particle [1441] beached !! (15.3 37.85 0 0)
# Particle [1476] beached !! (15 37.9 0 0)
# Particle [1477] beached !! (15.05 37.9 0 0)
# Particle [1478] beached !! (15.1 37.9 0 0)
# Particle [1479] beached !! (15.15 37.9 0 0)
# Particle [1480] beached !! (15.2 37.9 0 0)
# Particle [1481] beached !! (15.25 37.9 0 0)
# Particle [1482] beached !! (15.3 37.9 0 0)
# Particle [1517] beached !! (15 37.95 0 0)
# Particle [1518] beached !! (15.05 37.95 0 0)
# Particle [1519] beached !! (15.1 37.95 0 0)
# Particle [1520] beached !! (15.15 37.95 0 0)
# Particle [1521] beached !! (15.2 37.95 0 0)
# Particle [1522] beached !! (15.25 37.95 0 0)
# Particle [1523] beached !! (15.3 37.95 0 0)
# Particle [1524] beached !! (15.35 37.95 0 0)
# Particle [1531] beached !! (15.7 37.95 0 0)
# Particle [1532] beached !! (15.75 37.95 0 0)
# Particle [1533] beached !! (15.8 37.95 0 0)
# Particle [1534] beached !! (15.85 37.95 0 0)
# Particle [1535] beached !! (15.9 37.95 0 0)
# Particle [1536] beached !! (15.95 37.95 0 0)
# Particle [1537] beached !! (16 37.95 0 0)
# Particle [1538] beached !! (16.05 37.95 0 0)
# Particle [1558] beached !! (15 38 0 0)
# Particle [1559] beached !! (15.05 38 0 0)
# Particle [1560] beached !! (15.1 38 0 0)
# Particle [1561] beached !! (15.15 38 0 0)
# Particle [1562] beached !! (15.2 38 0 0)
# Particle [1563] beached !! (15.25 38 0 0)
# Particle [1564] beached !! (15.3 38 0 0)
# Particle [1565] beached !! (15.35 38 0 0)
# Particle [1571] beached !! (15.65 38 0 0)
# Particle [1572] beached !! (15.7 38 0 0)
# Particle [1573] beached !! (15.75 38 0 0)
# Particle [1574] beached !! (15.8 38 0 0)
# Particle [1575] beached !! (15.85 38 0 0)
# Particle [1576] beached !! (15.9 38 0 0)
# Particle [1577] beached !! (15.95 38 0 0)
# Particle [1578] beached !! (16 38 0 0)
# Particle [1579] beached !! (16.05 38 0 0)
# Particle [1580] beached !! (16.1 38 0 0)
# Particle [1599] beached !! (15 38.05 0 0)
# Particle [1600] beached !! (15.05 38.05 0 0)
# Particle [1601] beached !! (15.1 38.05 0 0)
# Particle [1602] beached !! (15.15 38.05 0 0)
# Particle [1603] beached !! (15.2 38.05 0 0)
# Particle [1604] beached !! (15.25 38.05 0 0)
# Particle [1605] beached !! (15.3 38.05 0 0)
# Particle [1606] beached !! (15.35 38.05 0 0)
# Particle [1607] beached !! (15.4 38.05 0 0)
# Particle [1608] beached !! (15.45 38.05 0 0)
# Particle [1612] beached !! (15.65 38.05 0 0)
# Particle [1613] beached !! (15.7 38.05 0 0)
# Particle [1614] beached !! (15.75 38.05 0 0)
# Particle [1615] beached !! (15.8 38.05 0 0)
# Particle [1616] beached !! (15.85 38.05 0 0)
# Particle [1617] beached !! (15.9 38.05 0 0)
# Particle [1618] beached !! (15.95 38.05 0 0)
# Particle [1619] beached !! (16 38.05 0 0)
# Particle [1620] beached !! (16.05 38.05 0 0)
# Particle [1621] beached !! (16.1 38.05 0 0)
# Particle [1640] beached !! (15 38.1 0 0)
# Particle [1641] beached !! (15.05 38.1 0 0)
# Particle [1642] beached !! (15.1 38.1 0 0)
# Particle [1643] beached !! (15.15 38.1 0 0)
# Particle [1644] beached !! (15.2 38.1 0 0)
# Particle [1645] beached !! (15.25 38.1 0 0)
# Particle [1646] beached !! (15.3 38.1 0 0)
# Particle [1647] beached !! (15.35 38.1 0 0)
# Particle [1648] beached !! (15.4 38.1 0 0)
# Particle [1649] beached !! (15.45 38.1 0 0)
# Particle [1650] beached !! (15.5 38.1 0 0)
# Particle [1653] beached !! (15.65 38.1 0 0)
# Particle [1654] beached !! (15.7 38.1 0 0)
# Particle [1655] beached !! (15.75 38.1 0 0)
# Particle [1656] beached !! (15.8 38.1 0 0)
# Particle [1657] beached !! (15.85 38.1 0 0)
# Particle [1658] beached !! (15.9 38.1 0 0)
# Particle [1659] beached !! (15.95 38.1 0 0)
# Particle [1660] beached !! (16 38.1 0 0)
# Particle [1661] beached !! (16.05 38.1 0 0)
# Particle [1662] beached !! (16.1 38.1 0 0)
# actual number of release positions (excluding land): 1499
# actual number of particles: 109427.0

# %% [markdown]
# ### 3.3 Perform trajectory integration and save trajectories in .zarr format

# %%
# %%time
for times in range(tstart_release, tend_release, deltat_release):
    
    if (key_sample_velocity == True):
        pclass_main = BeachCurrentParticle
        outpath_ending = "m_Sample-UV.zarr"
    else:
        pclass_main=BeachParticle
        outpath_ending = "m.zarr"
  
    ## create new clean particle set (including new clean fieldset)
    ### ensure that for each release date the particle numbering starts again from 0
    fieldset_main = create_fieldset(keystokes=key_stokes)
    BeachCurrentParticle.setLastID(0)
    BeachParticle.setLastID(0)
    pset_main = ParticleSet(fieldset=fieldset_main,
                            pclass=pclass_main,
                            lon=lons_use, lat=lats_use,
                            time=times*times_convert)   
    pset_main.populate_indices()
    
    ## define output
    ### ensure depth is not stored in trajectory output (depth not necessary for 2D calculations)
    pset_main.set_variable_write_status("depth", False) 
    outpath_final = (outpath + "-t" + str(times) 
                     + "_Integrate-fw-d" + str(tint) + "-dt" + str(deltat) 
                     + outpath_ending)
    outfile_final = pset_main.ParticleFile(outpath_final, 
                                           outputdt=timedelta(days=outdt))
  
    ## advect particle
    ## do not delete potentially beached particles, but keep them for statistics
    if (key_sample_velocity == True):
        kernels_main = (pset_main.Kernel(AdvectionRK4) + pset_main.Kernel(BeachTesting) 
                        + pset_main.Kernel(SampleUV))
    else:
        kernels_main = (pset_main.Kernel(AdvectionRK4) + pset_main.Kernel(BeachTesting))
    pset_main.execute(kernels_main,
                      runtime=timedelta(days=tint),
                      dt=timedelta(minutes=deltat),
                      output_file=outfile_final)
    
    pset_main.set_variable_write_status("depth", True) # somehow needed, otherwise next pset can not be build
# Out:
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib3b87d9e235148898d2a358ae2961e71d_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t0_Integrate-fw-d30-dt25m_Sample-UV.zarr.
# 100%|█████████▉| 2591100.0/2592000.0 [00:00<00:00, 14671468.70it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 11058356.31it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib4acad01b6d4b2f48d167c27734689644_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t5_Integrate-fw-d30-dt25m_Sample-UV.zarr.
# 100%|█████████▉| 2591100.0/2592000.0 [00:00<00:00, 14780956.82it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 11093324.97it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/libae1c87c4fd64028bd49c6126c4821a22_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 2.8512e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t10_Integrate-fw-d30-dt25m_Sample-UV.zarr.
# 100%|█████████▉| 2591100.0/2592000.0 [00:00<00:00, 14719995.63it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 11109932.92it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib264e4ea2c9d25fd3a8cb08e461271b42_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 2.8512e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t15_Integrate-fw-d30-dt25m_Sample-UV.zarr.
# 100%|█████████▉| 2591100.0/2592000.0 [00:00<00:00, 14869515.32it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 11365679.32it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib3a480e0257988a97b6a50f024a295259_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 2.9376e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t20_Integrate-fw-d30-dt25m_Sample-UV.zarr.
# 100%|█████████▉| 2591100.0/2592000.0 [00:00<00:00, 14906696.30it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 11316840.47it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/libd43072edb4445f0085e5b89c4467c92d_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1413] beached !! (15.8542 38.5838 0 3.5424e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t25_Integrate-fw-d30-dt25m_Sample-UV.zarr.
# 100%|█████████▉| 2591100.0/2592000.0 [00:00<00:00, 14631627.90it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 11144692.07it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib9d907e802dc71e4f3106ea4590943438_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 2.9376e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [895] beached !! (15.1875 37.25 0 4.6656e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t30_Integrate-fw-d30-dt25m_Sample-UV.zarr.
# 100%|█████████▉| 2591100.0/2592000.0 [00:00<00:00, 15093308.19it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 11509102.12it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib6f42f75fd674b5243276b62ca589b368_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [895] beached !! (15.1875 37.25 0 4.6656e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t35_Integrate-fw-d30-dt25m_Sample-UV.zarr.
# 100%|█████████▉| 2591100.0/2592000.0 [00:00<00:00, 14692950.31it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 11223596.74it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/libebde81fdb383b372dae9820e7b12ef34_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 3.7152e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [895] beached !! (15.1875 37.25 0 4.752e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t40_Integrate-fw-d30-dt25m_Sample-UV.zarr.
# 100%|█████████▉| 2591100.0/2592000.0 [00:00<00:00, 15111629.89it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 11420409.48it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib0ceb5980804376ac6b94ce6d33424d2d_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [719] beached !! (15.2708 37 0 4.752e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [895] beached !! (15.1875 37.25 0 5.0976e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 5.616e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t45_Integrate-fw-d30-dt25m_Sample-UV.zarr.
#   0%|          | 0/2592000.0 [00:00<?, ?it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
#  90%|█████████ | 2332800.0/2592000.0 [00:00<00:00, 13333268.43it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:01<00:00, 1779959.39it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib188f44a45df84fa7ba881dcf52ef9d1f_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [719] beached !! (15.2708 37 0 5.3568e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 5.7888e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib1e59791d0aea2a71ad7c88f4125bdcbe_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 6.2208e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib04ed03ca0eae6b7d21d27cd677e82b11_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/libd5f3427b44dac0cf3d36f512f401bb6a_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 6.2208e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t65_Integrate-fw-d30-dt25m_Sample-UV.zarr.
#   0%|          | 0/2592000.0 [00:00<?, ?it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 47497000.62it/s]
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib08370ffb409899ff8082004fdaa55826_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 6.6528e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib139097b53e3ca7e77abdcd4813e46513_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 6.6528e+06)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# ...
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib8f5c6dfcb4a8236935fb538d58cae009_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib2b8234f8a89d66948462b421ceb388c1_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib3bf1e85dce3d27b0584930cb60caecb8_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 3.0672e+07)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib954819b36c9b61ad600684ed200d9d2c_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 3.16224e+07)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Compiled ArrayBeachCurrentParticleAdvectionRK4BeachTestingSampleUV ==> /var/folders/bd/ct5yrfy51z7bdshm97c2w2nc0000gp/T/parcels-502/lib4238f158613405fb8d258d1a2da7fb68_0.so
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [1435] beached !! (15.3958 38 0 3.1536e+07)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# Particle [895] beached !! (15.1875 37.25 0 3.18816e+07)
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# INFO: Output files are stored in /Users/siren/IMMERSE_waves/develop-mac/data/Trajectories-revisedNEMO/SubReg9/Parcels_CalcTraj_Data-coupled-sd_Release-SubReg9-t360_Integrate-fw-d30-dt25m_Sample-UV.zarr.
#   0%|          | 0/2592000.0 [00:00<?, ?it/s]<__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# 100%|██████████| 2592000.0/2592000.0 [00:00<00:00, 47641658.78it/s]
# CPU times: user 1h 16min 6s, sys: 5min 7s, total: 1h 21min 13s
# Wall time: 1h 26min 43s

# %%
# Plotting of final positions 
## in this simple form only works for uncoupled simulation
## as Parcels plotting routine can not deal with summed fieldsets
PlotParticleSet(pset_main,fieldset_main)
